# %%
# This notebook plots filtered gyro speed data from the main.py file (rewrite later)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %%
# Read velocity data from csv file
filtered_speed = pd.read_csv('filtered_speed.csv')

# Read angle data from csv file
filtered_angle = pd.read_csv('filtered_angle.csv')

# %%
# Extract data

time = filtered_speed['time']
time /= 1000

low_pass_speed = filtered_speed[' low pass speed']
kalman_speed = filtered_speed[' kalman speed']

low_pass_angle = filtered_angle[' low pass angle']
kalman_angle = filtered_angle[' kalman angle']

# %%
# Plots

figure, axis = plt.subplots(2, 1, figsize=(12, 12))

# For filtered speeds
axis[0].plot(time, low_pass_speed, color='r', label='low_pass_speed')
axis[0].plot(time, kalman_speed, color='g', label='kalman_speed')
axis[0].set_title("Filtered speeds")
axis[0].set(xlabel='Time (s)')
axis[0].set(ylabel= 'Gyro speed (deg/s)')
axis[0].legend()

# For filtered angles
axis[1].plot(time, low_pass_angle, color='r', label='low_pass_angle')
axis[1].plot(time, kalman_angle, color='g', label='kalman_angle')
axis[1].set_title("Filtered angles")
axis[1].set(xlabel='Time (s)')
axis[1].set(ylabel= 'Gyro angle (deg)')
axis[1].legend()
